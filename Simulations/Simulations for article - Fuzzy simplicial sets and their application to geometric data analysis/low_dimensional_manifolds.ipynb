# %%
from helper_functions import *
PLOT_PATH = os.path.abspath(os.path.join(PLOT_PATH, "low_dimensional_manifolds"))

# %%
N = 5000

# %%
data, labels = createNonUniformHemisphere(N)
datasetName = "NonUniformHemisphere"
plot_data(data,labels, display=True, path=PLOT_PATH, title=datasetName+" original")
embedding = run_isumap(data, labels, datasetName=datasetName,plot_path=PLOT_PATH)
# Out:
# Number of CPU threads =  128
#
# Nearest neighbours computed in: 0.04 sec
#
# Normalization computed in: 6.29 sec
# Computing the graph...
#
# Graph computation: 0.84 sec
# Applying t-conorm...
#
# T-conorm application: 3.34 sec
#
# Running Dijkstra...
#
# Dijkstra: 5.20 sec
#
# Extracted connected components in: 4.03 sec
# Number of clusters = 1
#
# Mean points and labels: 0.00 sec
#
# Euclidean distances: 2.19 sec
#
# Performing classical MDS...
#
# classical MDS: 3.69 sec
#
# Embedded the cluster mean points in: 3.69 sec
#
# Reducing dimension...
#
# Performing classical MDS...
#
# classical MDS: 2.03 sec
#
# Performing metric MDS...
#  30%|███       | 304/1000 [00:16<00:38, 18.13it/s]
# Convergence. Early stopping at epoch 304!
#
# Computed submatrix embeddings in: 18.90 sec
#
# Isumap total time: 44.67 sec

# %%
data, labels = createTorus(N)
datasetName = "Torus"
plot_data(data,labels, display=True, path=PLOT_PATH, title=datasetName+" original")
embedding = run_isumap(data, labels, datasetName=datasetName,plot_path=PLOT_PATH)
# Out:
# Number of CPU threads =  128
#
# Nearest neighbours computed in: 0.03 sec
#
# Normalization computed in: 0.00 sec
# Computing the graph...
#
# Graph computation: 0.52 sec
# Applying t-conorm...
#
# T-conorm application: 3.70 sec
#
# Running Dijkstra...
#
# Dijkstra: 7.13 sec
#
# Extracted connected components in: 0.13 sec
# Number of clusters = 1
#
# Mean points and labels: 0.00 sec
#
# Euclidean distances: 0.01 sec
#
# Performing classical MDS...
#
# classical MDS: 0.00 sec
#
# Embedded the cluster mean points in: 0.00 sec
#
# Reducing dimension...
#
# Performing classical MDS...
#
# classical MDS: 1.05 sec
#
# Performing metric MDS...
#  22%|██▏       | 220/1000 [00:10<00:36, 21.21it/s]
# Convergence. Early stopping at epoch 220!
#
# Computed submatrix embeddings in: 11.48 sec
#
# Isumap total time: 23.18 sec

# %%
data, labels = createSwissRoll(N)
datasetName = "SwissRoll"
plot_data(data,labels, display=True, path=PLOT_PATH, title=datasetName+" original")
embedding = run_isumap(data, labels, datasetName=datasetName,plot_path=PLOT_PATH)
# Out:
# Number of CPU threads =  128
#
# Nearest neighbours computed in: 0.08 sec
#
# Normalization computed in: 0.00 sec
# Computing the graph...
#
# Graph computation: 1.53 sec
# Applying t-conorm...
#
# T-conorm application: 6.99 sec
#
# Running Dijkstra...
#
# Dijkstra: 8.15 sec
#
# Extracted connected components in: 0.13 sec
# Number of clusters = 1
#
# Mean points and labels: 0.00 sec
#
# Euclidean distances: 0.01 sec
#
# Performing classical MDS...
#
# classical MDS: 0.00 sec
#
# Embedded the cluster mean points in: 0.00 sec
#
# Reducing dimension...
#
# Performing classical MDS...
#
# classical MDS: 0.90 sec
#
# Performing metric MDS...
#  30%|███       | 304/1000 [00:17<00:39, 17.43it/s]
# Convergence. Early stopping at epoch 304!
#
# Computed submatrix embeddings in: 18.39 sec
#
# Isumap total time: 35.45 sec

# %%
data, labels = createSCurve(N)
datasetName = "Scurve"
plot_data(data,labels, display=True, path=PLOT_PATH, title=datasetName+" original")
embedding = run_isumap(data, labels, datasetName=datasetName,plot_path=PLOT_PATH)
# Out:
# Number of CPU threads =  128
#
# Nearest neighbours computed in: 0.03 sec
#
# Normalization computed in: 0.00 sec
# Computing the graph...
#
# Graph computation: 0.56 sec
# Applying t-conorm...
#
# T-conorm application: 3.46 sec
#
# Running Dijkstra...
#
# Dijkstra: 8.68 sec
#
# Extracted connected components in: 0.14 sec
# Number of clusters = 1
#
# Mean points and labels: 0.00 sec
#
# Euclidean distances: 0.01 sec
#
# Performing classical MDS...
#
# classical MDS: 0.01 sec
#
# Embedded the cluster mean points in: 0.01 sec
#
# Reducing dimension...
#
# Performing classical MDS...
#
# classical MDS: 0.89 sec
#
# Performing metric MDS...
#  52%|█████▏    | 519/1000 [00:22<00:21, 22.62it/s]
# Convergence. Early stopping at epoch 519!
#
# Computed submatrix embeddings in: 23.90 sec
#
# Isumap total time: 37.02 sec

# %%
data, labels = createMammoth(N,datasetPath=datasetPath)
datasetName = "Mammoth"
plot_data(data,labels, display=True, path=PLOT_PATH, title=datasetName+" original")
embedding = run_isumap(data, labels, datasetName=datasetName,plot_path=PLOT_PATH,plotMetricMDS=True)
# Out:
# Number of CPU threads =  128
#
# Nearest neighbours computed in: 0.03 sec
#
# Normalization computed in: 5.91 sec
# Computing the graph...
#
# Graph computation: 0.81 sec
# Applying t-conorm...
#
# T-conorm application: 3.47 sec
#
# Running Dijkstra...
#
# Dijkstra: 4.86 sec
#
# Extracted connected components in: 3.30 sec
# Number of clusters = 1
#
# Mean points and labels: 0.00 sec
#
# Euclidean distances: 2.06 sec
#
# Performing classical MDS...
#
# classical MDS: 3.69 sec
#
# Embedded the cluster mean points in: 3.69 sec
#
# Reducing dimension...
#
# Performing classical MDS...
#
# classical MDS: 2.84 sec
#
# Performing metric MDS...
#  68%|██████▊   | 676/1000 [00:35<00:17, 18.99it/s]
# Convergence. Early stopping at epoch 676!
#
# Computed submatrix embeddings in: 38.53 sec
#
# Isumap total time: 62.82 sec
